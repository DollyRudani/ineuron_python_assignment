# %% [markdown]
# 1. Write a python program to print "Hello Python" ?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# 2. Write a python program to do arithemetical operations addition and division.?

# %%
a = int(input('enter a num: '))
b = int(input('enter a num: '))

print(a+b)
print(a/b)
print(a//b)
# Out:
# enter a num: 8
# enter a num: 2
# 10
# 4.0
# 4

# %% [markdown]
# 3. Write a python program to find are of a triangle ?

# %%
b = int(input('enter base: '))
h = int(input('enter height: '))
area = (b*h)/2
print(area)
# Out:
# enter base: 8
# enter height: 4
# 16.0

# %% [markdown]
# 4. Write a python program to swap two variables?

# %%
a = int(input("enter first num: "))
b = int(input("enter second num: "))

a,b = b,a

print(a)
print(b)
# Out:
# enter first num: 6
# enter second num: 4
# 4
# 6

# %% [markdown]
# 5. Write a python program to generate a random number?

# %%
import random
a = random.randint(0,10)
print(a)
# Out:
# 3
